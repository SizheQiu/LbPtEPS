# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import seaborn as sns

# %% [markdown]
# # Pre-experiment: growth with pH control

# %%
growth_data = (pd.read_csv('../data/Exp_data/GrowthpHcontrol_pre.csv')).dropna()
growth_data = growth_data.drop(['Time'],axis=1)

# %%
timepts, samples, od600 = [],[],[]
for i in range(len(growth_data.columns)):
    for j in range(len(growth_data.index)):
        samples.append( growth_data.columns[i].split('_')[0].strip() )
        timepts.append( int(j) )
        od600.append( growth_data.iloc[j][i] )
temp_pd = pd.DataFrame(zip(timepts, samples, od600),columns=['Time','Sample','OD600'])

# %%
fig,ax = plt.subplots(figsize=(10,5))
sns.lineplot(x="Time", y="OD600",
             hue="Sample", 
             data=temp_pd,ax=ax)
ax.set_xticks(np.arange(0,25));
ax.set_xlim([-0.5,24.5])
ax.grid()

# %% [markdown]
# # Process proteomics dataset

# %%
proA, proB = pd.read_excel('../data/Proteomics/Proteomics_A.xlsx'), pd.read_excel('../data/Proteomics/Proteomics_B.xlsx') 
proA = proA[ ['Accession','Gene Name'] + list(proA.columns[-12:])].fillna(0)
proB = proB[ ['Accession','Gene Name'] + list(proB.columns[-12:])].fillna(0)

# %%
proAB = proA.merge(proB, left_on=['Accession','Gene Name'], right_on= ['Accession','Gene Name'],how='inner')

# %%
# proAB.to_csv('../data/Proteomics/Proteomics_AB.csv',index=None)

# %%
X = (proAB.iloc[:,2:].values).T
Xstd = StandardScaler().fit_transform(X)
pca_transform = PCA(n_components=3)
X_pca = pca_transform.fit_transform(X)

# %%
print(pca_transform.explained_variance_ratio_)
# Out:
# [0.89372807 0.04663968 0.0290931 ]

# %%
samples = list( proAB.columns[2:] )
X_pca_pd = pd.DataFrame(X_pca, columns=['PC1(89.4%)','PC2(4.7%)','PC3(2.9%)'])
X_pca_pd['Batch'] = [x.split('-')[1][0] for x in samples]
X_pca_pd['Condition'] = [x.split('-')[0] for x in samples]

# %%
fig, axs = plt.subplots(1,3,figsize=(15,4))
sns.scatterplot(data=X_pca_pd, x="PC1(89.4%)", y="PC2(4.7%)", hue="Condition", style="Batch",\
                s=50,linewidth=0.5,edgecolor='black',ax= axs[0])
sns.scatterplot(data=X_pca_pd, x="PC1(89.4%)", y="PC3(2.9%)", hue="Condition", style="Batch",\
                s=50,linewidth=0.5, edgecolor='black',ax= axs[1])
sns.scatterplot(data=X_pca_pd, x="PC2(4.7%)", y="PC3(2.9%)", hue="Condition", style="Batch",\
                s=50,linewidth=0.5, edgecolor='black',ax= axs[2])
plt.suptitle('PCA(n=3) of proteomics')
# Out:
# Text(0.5, 0.98, 'PCA(n=3) of proteomics')
